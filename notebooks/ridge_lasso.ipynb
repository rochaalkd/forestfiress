# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Algerian_forest_fires_dataset_UPDATE (1).csv')

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
#  RH            2
#  Ws            2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# dtype: int64

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=247, step=1),
#  Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#         'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#        dtype='object')]

# %%
df['day']
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#        ..
# 242    26
# 243    27
# 244    28
# 245    29
# 246    30
# Name: day, Length: 247, dtype: object

# %%
df.index=df['day']

# %%
df.head()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# day
# 1     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 2     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 3     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 4     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 5     5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes
# day
# 1    not fire
# 2    not fire
# 3    not fire
# 4    not fire
# 5    not fire

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                                          day month  year  \
# day
# NaN                                                      NaN   NaN   NaN
# Sidi-Bel Abbes Region Dataset  Sidi-Bel Abbes Region Dataset   NaN   NaN
# 14                                                        14     7  2012
#
#                               Temperature   RH   Ws Rain   FFMC   DMC      DC  \
# day
# NaN                                   NaN  NaN  NaN   NaN   NaN   NaN     NaN
# Sidi-Bel Abbes Region Dataset         NaN  NaN  NaN   NaN   NaN   NaN     NaN
# 14                                     37   37   18   0.2  88.9  12.9  14.6 9
#
#                                 ISI   BUI      FWI Classes
# day
# NaN                             NaN   NaN      NaN       NaN
# Sidi-Bel Abbes Region Dataset   NaN   NaN      NaN       NaN
# 14                             12.5  10.4  fire          NaN

# %%
df.loc[:122,"Region"]=0
df.loc[122:,"Region"]=1
# Out:
# C:\Users\Rocha\AppData\Local\Temp\ipykernel_19952\4042013598.py:1: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   df.loc[:122,"Region"]=0
# C:\Users\Rocha\AppData\Local\Temp\ipykernel_19952\4042013598.py:2: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   df.loc[122:,"Region"]=1

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# day
# 1     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 2     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 3     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 4     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 5     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 26   26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 27   27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 28   28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 29   29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 30   30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# day
# 1    0.5   not fire        0.0
# 2    0.4   not fire        0.0
# 3    0.1   not fire        0.0
# 4      0   not fire        0.0
# 5    0.5   not fire        0.0
# ..   ...           ...     ...
# 26   6.5       fire        1.0
# 27     0   not fire        1.0
# 28   0.2   not fire        1.0
# 29   0.7   not fire        1.0
# 30   0.5  not fire         1.0
#
# [247 rows x 15 columns]

# %%
df[['Region']]=df[['Region']].astype(int)

# %%
df.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
#  RH            2
#  Ws            2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# Region         0
# dtype: int64

# %%
df=df.dropna().reset_index(drop=True)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
df=df.drop(122).reset_index(drop=True)

# %%
df.columns=df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 27.7+ KB

# %%
df[['month','day','year','Temperature','RH','Ws']]=df[['month','day','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: int32(7), object(8)
# memory usage: 22.0+ KB

# %%
df[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']]=df[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.0+ KB

# %%
df.to_csv('Algerian_cleaned_dataset',index=False)

# %%
df_copy=df.drop(['day','month','year'],axis=1)

# %%
df['Classes'].value_counts()
# Out:
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
df_copy['Classes']=np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy['Classes'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Classes, dtype: int32

# %%
df.corr()
# Out:
#                   day     month  year  Temperature        RH        Ws  \
# day          1.000000 -0.000369   NaN     0.097227 -0.076034  0.047812
# month       -0.000369  1.000000   NaN    -0.056781 -0.041252 -0.039880
# year              NaN       NaN   NaN          NaN       NaN       NaN
# Temperature  0.097227 -0.056781   NaN     1.000000 -0.651400 -0.284510
# RH          -0.076034 -0.041252   NaN    -0.651400  1.000000  0.244048
# Ws           0.047812 -0.039880   NaN    -0.284510  0.244048  1.000000
# Rain        -0.112523  0.034822   NaN    -0.326492  0.222356  0.171506
# FFMC         0.224956  0.017030   NaN     0.676568 -0.644873 -0.166548
# DMC          0.491514  0.067943   NaN     0.485687 -0.408519 -0.000721
# DC           0.527952  0.126511   NaN     0.376284 -0.226941  0.079135
# ISI          0.180543  0.065608   NaN     0.603871 -0.686667  0.008532
# BUI          0.517117  0.085073   NaN     0.459789 -0.353841  0.031438
# FWI          0.350781  0.082639   NaN     0.566670 -0.580957  0.032368
# Region       0.000821  0.001857   NaN     0.269555 -0.402682 -0.181160
#
#                  Rain      FFMC       DMC        DC       ISI       BUI  \
# day         -0.112523  0.224956  0.491514  0.527952  0.180543  0.517117
# month        0.034822  0.017030  0.067943  0.126511  0.065608  0.085073
# year              NaN       NaN       NaN       NaN       NaN       NaN
# Temperature -0.326492  0.676568  0.485687  0.376284  0.603871  0.459789
# RH           0.222356 -0.644873 -0.408519 -0.226941 -0.686667 -0.353841
# Ws           0.171506 -0.166548 -0.000721  0.079135  0.008532  0.031438
# Rain         1.000000 -0.543906 -0.288773 -0.298023 -0.347484 -0.299852
# FFMC        -0.543906  1.000000  0.603608  0.507397  0.740007  0.592011
# DMC         -0.288773  0.603608  1.000000  0.875925  0.680454  0.982248
# DC          -0.298023  0.507397  0.875925  1.000000  0.508643  0.941988
# ISI         -0.347484  0.740007  0.680454  0.508643  1.000000  0.644093
# BUI         -0.299852  0.592011  0.982248  0.941988  0.644093  1.000000
# FWI         -0.324422  0.691132  0.875864  0.739521  0.922895  0.857973
# Region      -0.040013  0.222241  0.192089 -0.078734  0.263197  0.089408
#
#                   FWI    Region
# day          0.350781  0.000821
# month        0.082639  0.001857
# year              NaN       NaN
# Temperature  0.566670  0.269555
# RH          -0.580957 -0.402682
# Ws           0.032368 -0.181160
# Rain        -0.324422 -0.040013
# FFMC         0.691132  0.222241
# DMC          0.875864  0.192089
# DC           0.739521 -0.078734
# ISI          0.922895  0.263197
# BUI          0.857973  0.089408
# FWI          1.000000  0.197102
# Region       0.197102  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>
